# %% [markdown]
# ###Load Data

# %%
import torch
import torch.nn as nn
from torchvision import datasets ,models,transforms
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from torch.nn import Linear, ReLU, CrossEntropyLoss, Conv2d, MaxPool2d, Module
from torch.optim import Adam
import pandas as pd
import os, shutil
from os import listdir
from tqdm import tqdm_notebook as tqdm
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!gdown --id '16k0608XLsNcCWvX9mawqv_ojAHQB7aa9'
#!unzip -q OneDrive-2021-12-12.zip
#https://drive.google.com/drive/folders/1KGXp-WE5SJ1xQqU9EQWsXNVA17XWS84w?usp=sharing
#https://drive.google.com/u/0/uc?id=17BZWzb-FTx00cJAIrTHKogXdaZVuUtiM&export=download
#https://drive.google.com/u/0/uc?export=download&confirm=dlti&id=17BZWzb-FTx00cJAIrTHKogXdaZVuUtiM
#https://drive.google.com/file/d/1l8YzfPxHeMuLfUdSILbbb7gK98d3a9Ja/view?usp=sharing
# !gdown --id '1l8YzfPxHeMuLfUdSILbbb7gK98d3a9Ja'
# !unzip -q split_.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1l8YzfPxHeMuLfUdSILbbb7gK98d3a9Ja
# To: /content/split_.zip
# 100% 4.56G/4.56G [00:25<00:00, 176MB/s]

# %%
# check
path, dirs, files = next(os.walk("content/drive/MyDrive/split/train/negative"))
print("train neg ",len(files))
path, dirs, files = next(os.walk("content/drive/MyDrive/split/train/positive"))
print("train pos ",len(files))
path, dirs, files = next(os.walk("content/drive/MyDrive/split/test/negative"))
print("test neg ",len(files))
path, dirs, files = next(os.walk("content/drive/MyDrive/split/test/positive"))
print("test pos ",len(files))
path, dirs, files = next(os.walk("content/drive/MyDrive/split/val/negative"))
print("val neg ",len(files))
path, dirs, files = next(os.walk("content/drive/MyDrive/split/val/positive"))
print("val pos ",len(files))
# Out:
# train neg  2484
# train pos  2484
# test neg  359
# test pos  45
# val neg  363
# val pos  44

# %% [markdown]
# ### Transform to tensor

# %%
# raw img size 4040 * 5416 pixel
wid = 1000
hgt = 1000

train_tfm = transforms.Compose([
    transforms.Resize((1000, 1000)),
    # transforms.ColorJitter(contrast=1),
    # transforms.RandomRotation(degrees = 8, fill = 1),
    # transforms.Resize((128, 128)),
    # transforms.RandomHorizontalFlip(p=0.5),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
])

test_tfm = transforms.Compose([
    transforms.Resize((1000, 1000)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
])

# input[512, 1, 28, 28]

# %% [markdown]
# ### Build Dataset

# %%
batch_size = 16
#train_set = datasets.DatasetFolder("split/train", loader=lambda x: Image.open(x), extensions="jpg", transform=train_tfm)
subtrain_set = datasets.DatasetFolder("content/drive/MyDrive/split/train", loader=lambda x: Image.open(x), extensions="jpg", transform=train_tfm)
valid_set = datasets.DatasetFolder("content/drive/MyDrive/split/val", loader=lambda x: Image.open(x), extensions="jpg", transform=test_tfm)
test_set = datasets.DatasetFolder("content/drive/MyDrive/split/test", loader=lambda x: Image.open(x), extensions="jpg", transform=test_tfm)

#train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True) # , num_workers=8, pin_memory=True
subtrain_loader = DataLoader(subtrain_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
print("Get length:", len(subtrain_set))
print("Get training data at position 3: ", subtrain_set[3])
# Out:
# Get length: 4968
# Get training data at position 3:  (tensor([[[0.8157, 0.8039, 0.7922,  ..., 0.1137, 0.1137, 0.1137],
#          [0.7961, 0.7882, 0.7804,  ..., 0.1098, 0.1098, 0.1059],
#          [0.7725, 0.7765, 0.7765,  ..., 0.1098, 0.1020, 0.0980],
#          ...,
#          [0.4039, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4078, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4157, 0.4118, 0.4078,  ..., 0.2471, 0.2588, 0.2667]],
#
#         [[0.8157, 0.8039, 0.7922,  ..., 0.1137, 0.1137, 0.1137],
#          [0.7961, 0.7882, 0.7804,  ..., 0.1098, 0.1098, 0.1059],
#          [0.7725, 0.7765, 0.7765,  ..., 0.1098, 0.1020, 0.0980],
#          ...,
#          [0.4039, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4078, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4157, 0.4118, 0.4078,  ..., 0.2471, 0.2588, 0.2667]],
#
#         [[0.8157, 0.8039, 0.7922,  ..., 0.1137, 0.1137, 0.1137],
#          [0.7961, 0.7882, 0.7804,  ..., 0.1098, 0.1098, 0.1059],
#          [0.7725, 0.7765, 0.7765,  ..., 0.1098, 0.1020, 0.0980],
#          ...,
#          [0.4039, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4078, 0.4039, 0.4039,  ..., 0.2471, 0.2627, 0.2706],
#          [0.4157, 0.4118, 0.4078,  ..., 0.2471, 0.2588, 0.2667]]]), 0)

# %%
subtrain_set[0][0].shape
# Out:
# torch.Size([3, 1000, 1000])

# %% [markdown]
# ### MLP (博任)

# %%
# dataiter = iter(train_loader)
# images, labels = dataiter.next()

# print(images.shape)
# print(labels.shape)
#CUDA_LAUNCH_BLOCKING=1
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
#get number of input features
#D_in = 3*5416*4040
D_in = 1000*1000
H = 56
#Binary classification problem
D_out = 1
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Running on device: ", device)
'''
net = torch.nn.Sequential(
        torch.nn.Linear(D_in, H),  
        torch.nn.ReLU(),
        torch.nn.Linear(H, H),
        torch.nn.ReLU(),
        torch.nn.Linear(H, D_out),
        torch.nn.Sigmoid()
)
'''
class model(nn.Module): # 2 types: real, fake
    def __init__(self, backbone): # positive parameter means grl or not, True: not grl
        super(model, self).__init__()
        # self.convert = nn.Conv2d(1, 3, 2)
        self.backbone = backbone
        self.classifier = nn.Sequential(
            nn.Linear(1000, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        # print('ori = ', x.shape)
        # x = self.convert(x)
        # print(x.shape)
        x = self.backbone(x)
      
        x = self.classifier(x)

        return x

backbone = torchvision.models.resnet18(pretrained=True)
#下面這個model更猛，但你可能跑不動
#backbone = torchvision.models.resnext101_32x8d(pretrained=True)

my_model = model(backbone)

# move the model to device (i.e., cpu or gpu)
my_model = my_model.to(device)
# Out:
# Running on device:  cuda
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
# define the optimizer
optimizer = torch.optim.Adam(my_model.parameters(), lr=0.0001)
# Binary Cross Entropy Loss
loss_fn = torch.nn.BCELoss()
#loss_fn = nn.BCEWithLogitsLoss()

# %%
nepoch = 200
step_count = 0
log_interval = 10
trainingAccuracy_list = []
validationAccuracy_list = []
trainingloss_list = []
validloss_list = []
step_count_list = []
train_ncorrect = 0
train_test_nobs = 0
cumulative_loss = 0
countdown = 100


for epoch_id in range(0, nepoch):    
    if countdown == 0:
        print("early stop2")
        break  
    for batch_idx, (inputs, targets) in enumerate(subtrain_loader):
        #reshape target to two-dimensional array
        targets = targets.reshape((-1, 1))
        step_count += 1        
        my_model.train()
        #print(inputs)
        #print(targets)
        inputs, targets = inputs.to(device), targets.to(device)
      
        optimizer.zero_grad()
        outputs = my_model(inputs)   
        targets = targets.float()
        loss = loss_fn(outputs, targets)
        cumulative_loss += loss

        train_pred = (outputs.cpu().detach().numpy() > 0.5).astype('float32')
        train_tmp_correct = (train_pred == targets.cpu().detach().numpy()).sum()
        train_ncorrect += train_tmp_correct
        train_test_nobs += len(train_pred) 
  
        loss.backward()
        optimizer.step()
        #if step_count % log_interval == 0: 
        if step_count % log_interval == 0:
            step_count_list.append(step_count)
            trainingAccuracy = train_ncorrect / train_test_nobs
            valid_ncorrect = 0
            valid_test_nobs = 0
            validoutputs_list = []
            validtargets_list = []
            with torch.no_grad():
              for i, (validinputs, validtargets) in enumerate(valid_loader):
                if i == 0:
                  print("Calculating Validation Accuracy...")
                my_model.eval()
                validtargets = validtargets.reshape((-1, 1))
                validinputs, validtargets = validinputs.to(device), validtargets.to(device)
                validoutputs = my_model(validinputs) 
                validtargets = validtargets.float()
                validoutputs_list.append(validoutputs)
                validtargets_list.append(validtargets)
                valid_pred = (validoutputs.cpu().detach().numpy() > 0.5).astype('float32')
                valid_tmp_correct = (valid_pred == validtargets.cpu().detach().numpy()).sum()
                valid_ncorrect += valid_tmp_correct
                valid_test_nobs += len(valid_pred) 
            validationAccuracy = valid_ncorrect / valid_test_nobs
            validoutputs_array = np.array(validoutputs_list)
            for i in range(len(validoutputs_array)):
              validoutputs_array[i] = validoutputs_array[i].to("cpu")
              validoutputs_array[i] = validoutputs_array[i].numpy()
            full_valid_outputs = np.concatenate(validoutputs_array, axis=0 )
            validtargets_array = np.array(validtargets_list)
            for i in range(len(validtargets_array)):
              validtargets_array[i] = validtargets_array[i].to("cpu")
              validtargets_array[i] = validtargets_array[i].numpy()
            full_valid_targets = np.concatenate(validtargets_array, axis=0 )
            validloss = loss_fn(torch.tensor(full_valid_outputs), torch.tensor(full_valid_targets))
            trainingloss = cumulative_loss / step_count
            trainingAccuracy_list.append(trainingAccuracy)
            validationAccuracy_list.append(validationAccuracy)
            trainingloss_list.append(trainingloss.item())
            validloss_list.append(validloss.item())
            print("Epoch %d Batch %d: trainingLoss = %.3f, validationLoss = %.3f (minibatch size = %d)" % (epoch_id, step_count, trainingloss.item(), validloss.item(), len(targets)))
            print("Epoch %d Batch %d: trainingAccuracy = %.3f, validationAccuracy = %.3f (minibatch size = %d)" % (epoch_id, step_count, trainingAccuracy, validationAccuracy, len(targets)))        
            if step_count < 20:
                before_lowestloss = validloss
                PATH = './resnet18_new2.pth' #save model
                torch.save(my_model.state_dict(), PATH)
                # !cp resnet18_new2.pth "drive/My Drive"
            elif step_count >=20:
                if validloss < before_lowestloss:
                    print("Oh yah") #爽啦，進步了！
                    PATH = './resnet18_new2.pth' #save model
                    torch.save(my_model.state_dict(), PATH)
                    # !cp resnet18_new2.pth "drive/My Drive"
                    before_lowestloss = validloss
                    countdown = 100 #經過1000個batch相當於經過100個10個batch
                else:
                    countdown -= 1
            if countdown == 0:
                print("early stop1") #好了啦
                break
# Out:
# Calculating Validation Accuracy...
# Epoch 0 Batch 10: trainingLoss = 0.757, validationLoss = 0.643 (minibatch size = 16)
# Epoch 0 Batch 10: trainingAccuracy = 0.575, validationAccuracy = 0.624 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 20: trainingLoss = 0.750, validationLoss = 0.596 (minibatch size = 16)
# Epoch 0 Batch 20: trainingAccuracy = 0.581, validationAccuracy = 0.656 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 0 Batch 30: trainingLoss = 0.727, validationLoss = 0.512 (minibatch size = 16)
# Epoch 0 Batch 30: trainingAccuracy = 0.613, validationAccuracy = 0.730 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 0 Batch 40: trainingLoss = 0.708, validationLoss = 0.723 (minibatch size = 16)
# Epoch 0 Batch 40: trainingAccuracy = 0.623, validationAccuracy = 0.602 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 50: trainingLoss = 0.704, validationLoss = 1.213 (minibatch size = 16)
# Epoch 0 Batch 50: trainingAccuracy = 0.621, validationAccuracy = 0.194 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 60: trainingLoss = 0.694, validationLoss = 0.646 (minibatch size = 16)
# Epoch 0 Batch 60: trainingAccuracy = 0.631, validationAccuracy = 0.717 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 70: trainingLoss = 0.666, validationLoss = 0.534 (minibatch size = 16)
# Epoch 0 Batch 70: trainingAccuracy = 0.653, validationAccuracy = 0.759 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 80: trainingLoss = 0.663, validationLoss = 0.428 (minibatch size = 16)
# Epoch 0 Batch 80: trainingAccuracy = 0.654, validationAccuracy = 0.806 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 0 Batch 90: trainingLoss = 0.665, validationLoss = 0.814 (minibatch size = 16)
# Epoch 0 Batch 90: trainingAccuracy = 0.652, validationAccuracy = 0.536 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 100: trainingLoss = 0.656, validationLoss = 0.541 (minibatch size = 16)
# Epoch 0 Batch 100: trainingAccuracy = 0.657, validationAccuracy = 0.722 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 110: trainingLoss = 0.651, validationLoss = 0.770 (minibatch size = 16)
# Epoch 0 Batch 110: trainingAccuracy = 0.661, validationAccuracy = 0.518 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 120: trainingLoss = 0.641, validationLoss = 0.839 (minibatch size = 16)
# Epoch 0 Batch 120: trainingAccuracy = 0.668, validationAccuracy = 0.558 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 130: trainingLoss = 0.638, validationLoss = 0.402 (minibatch size = 16)
# Epoch 0 Batch 130: trainingAccuracy = 0.671, validationAccuracy = 0.821 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 0 Batch 140: trainingLoss = 0.628, validationLoss = 0.404 (minibatch size = 16)
# Epoch 0 Batch 140: trainingAccuracy = 0.675, validationAccuracy = 0.811 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 150: trainingLoss = 0.624, validationLoss = 1.049 (minibatch size = 16)
# Epoch 0 Batch 150: trainingAccuracy = 0.678, validationAccuracy = 0.410 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 160: trainingLoss = 0.630, validationLoss = 0.645 (minibatch size = 16)
# Epoch 0 Batch 160: trainingAccuracy = 0.675, validationAccuracy = 0.622 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 170: trainingLoss = 0.629, validationLoss = 0.579 (minibatch size = 16)
# Epoch 0 Batch 170: trainingAccuracy = 0.675, validationAccuracy = 0.727 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 180: trainingLoss = 0.622, validationLoss = 0.589 (minibatch size = 16)
# Epoch 0 Batch 180: trainingAccuracy = 0.683, validationAccuracy = 0.725 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 190: trainingLoss = 0.617, validationLoss = 0.774 (minibatch size = 16)
# Epoch 0 Batch 190: trainingAccuracy = 0.686, validationAccuracy = 0.617 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 200: trainingLoss = 0.613, validationLoss = 0.547 (minibatch size = 16)
# Epoch 0 Batch 200: trainingAccuracy = 0.688, validationAccuracy = 0.747 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 210: trainingLoss = 0.610, validationLoss = 0.547 (minibatch size = 16)
# Epoch 0 Batch 210: trainingAccuracy = 0.689, validationAccuracy = 0.720 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 220: trainingLoss = 0.605, validationLoss = 0.666 (minibatch size = 16)
# Epoch 0 Batch 220: trainingAccuracy = 0.693, validationAccuracy = 0.663 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 230: trainingLoss = 0.604, validationLoss = 0.627 (minibatch size = 16)
# Epoch 0 Batch 230: trainingAccuracy = 0.693, validationAccuracy = 0.703 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 240: trainingLoss = 0.601, validationLoss = 0.432 (minibatch size = 16)
# Epoch 0 Batch 240: trainingAccuracy = 0.694, validationAccuracy = 0.811 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 250: trainingLoss = 0.601, validationLoss = 0.663 (minibatch size = 16)
# Epoch 0 Batch 250: trainingAccuracy = 0.694, validationAccuracy = 0.641 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 260: trainingLoss = 0.597, validationLoss = 0.683 (minibatch size = 16)
# Epoch 0 Batch 260: trainingAccuracy = 0.696, validationAccuracy = 0.624 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 270: trainingLoss = 0.593, validationLoss = 0.554 (minibatch size = 16)
# Epoch 0 Batch 270: trainingAccuracy = 0.699, validationAccuracy = 0.764 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 280: trainingLoss = 0.590, validationLoss = 0.603 (minibatch size = 16)
# Epoch 0 Batch 280: trainingAccuracy = 0.701, validationAccuracy = 0.690 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 290: trainingLoss = 0.589, validationLoss = 0.610 (minibatch size = 16)
# Epoch 0 Batch 290: trainingAccuracy = 0.703, validationAccuracy = 0.715 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 300: trainingLoss = 0.587, validationLoss = 0.416 (minibatch size = 16)
# Epoch 0 Batch 300: trainingAccuracy = 0.705, validationAccuracy = 0.865 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 0 Batch 310: trainingLoss = 0.585, validationLoss = 0.392 (minibatch size = 16)
# Epoch 0 Batch 310: trainingAccuracy = 0.705, validationAccuracy = 0.821 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 1 Batch 320: trainingLoss = 0.583, validationLoss = 0.388 (minibatch size = 16)
# Epoch 1 Batch 320: trainingAccuracy = 0.706, validationAccuracy = 0.821 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 1 Batch 330: trainingLoss = 0.580, validationLoss = 0.561 (minibatch size = 16)
# Epoch 1 Batch 330: trainingAccuracy = 0.709, validationAccuracy = 0.740 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 340: trainingLoss = 0.575, validationLoss = 0.389 (minibatch size = 16)
# Epoch 1 Batch 340: trainingAccuracy = 0.712, validationAccuracy = 0.845 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 350: trainingLoss = 0.571, validationLoss = 0.506 (minibatch size = 16)
# Epoch 1 Batch 350: trainingAccuracy = 0.714, validationAccuracy = 0.796 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 360: trainingLoss = 0.570, validationLoss = 0.618 (minibatch size = 16)
# Epoch 1 Batch 360: trainingAccuracy = 0.716, validationAccuracy = 0.678 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 370: trainingLoss = 0.568, validationLoss = 0.736 (minibatch size = 16)
# Epoch 1 Batch 370: trainingAccuracy = 0.718, validationAccuracy = 0.560 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 380: trainingLoss = 0.564, validationLoss = 0.481 (minibatch size = 16)
# Epoch 1 Batch 380: trainingAccuracy = 0.720, validationAccuracy = 0.796 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 390: trainingLoss = 0.562, validationLoss = 0.387 (minibatch size = 16)
# Epoch 1 Batch 390: trainingAccuracy = 0.721, validationAccuracy = 0.848 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 1 Batch 400: trainingLoss = 0.560, validationLoss = 1.136 (minibatch size = 16)
# Epoch 1 Batch 400: trainingAccuracy = 0.722, validationAccuracy = 0.447 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 410: trainingLoss = 0.560, validationLoss = 0.446 (minibatch size = 16)
# Epoch 1 Batch 410: trainingAccuracy = 0.722, validationAccuracy = 0.791 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 420: trainingLoss = 0.557, validationLoss = 0.414 (minibatch size = 16)
# Epoch 1 Batch 420: trainingAccuracy = 0.724, validationAccuracy = 0.823 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 430: trainingLoss = 0.555, validationLoss = 0.399 (minibatch size = 16)
# Epoch 1 Batch 430: trainingAccuracy = 0.725, validationAccuracy = 0.833 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 440: trainingLoss = 0.553, validationLoss = 0.879 (minibatch size = 16)
# Epoch 1 Batch 440: trainingAccuracy = 0.727, validationAccuracy = 0.486 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 450: trainingLoss = 0.553, validationLoss = 0.760 (minibatch size = 16)
# Epoch 1 Batch 450: trainingAccuracy = 0.727, validationAccuracy = 0.604 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 460: trainingLoss = 0.551, validationLoss = 0.974 (minibatch size = 16)
# Epoch 1 Batch 460: trainingAccuracy = 0.728, validationAccuracy = 0.491 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 470: trainingLoss = 0.549, validationLoss = 0.652 (minibatch size = 16)
# Epoch 1 Batch 470: trainingAccuracy = 0.730, validationAccuracy = 0.656 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 480: trainingLoss = 0.549, validationLoss = 0.497 (minibatch size = 16)
# Epoch 1 Batch 480: trainingAccuracy = 0.729, validationAccuracy = 0.767 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 490: trainingLoss = 0.549, validationLoss = 0.388 (minibatch size = 16)
# Epoch 1 Batch 490: trainingAccuracy = 0.730, validationAccuracy = 0.833 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 500: trainingLoss = 0.548, validationLoss = 0.571 (minibatch size = 16)
# Epoch 1 Batch 500: trainingAccuracy = 0.730, validationAccuracy = 0.717 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 510: trainingLoss = 0.547, validationLoss = 0.464 (minibatch size = 16)
# Epoch 1 Batch 510: trainingAccuracy = 0.730, validationAccuracy = 0.786 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 520: trainingLoss = 0.544, validationLoss = 0.399 (minibatch size = 16)
# Epoch 1 Batch 520: trainingAccuracy = 0.733, validationAccuracy = 0.835 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 530: trainingLoss = 0.541, validationLoss = 0.408 (minibatch size = 16)
# Epoch 1 Batch 530: trainingAccuracy = 0.735, validationAccuracy = 0.853 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 540: trainingLoss = 0.539, validationLoss = 0.375 (minibatch size = 16)
# Epoch 1 Batch 540: trainingAccuracy = 0.737, validationAccuracy = 0.875 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 1 Batch 550: trainingLoss = 0.536, validationLoss = 0.383 (minibatch size = 16)
# Epoch 1 Batch 550: trainingAccuracy = 0.739, validationAccuracy = 0.850 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 560: trainingLoss = 0.535, validationLoss = 1.007 (minibatch size = 16)
# Epoch 1 Batch 560: trainingAccuracy = 0.740, validationAccuracy = 0.396 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 570: trainingLoss = 0.535, validationLoss = 0.593 (minibatch size = 16)
# Epoch 1 Batch 570: trainingAccuracy = 0.741, validationAccuracy = 0.676 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 580: trainingLoss = 0.534, validationLoss = 0.480 (minibatch size = 16)
# Epoch 1 Batch 580: trainingAccuracy = 0.741, validationAccuracy = 0.771 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 590: trainingLoss = 0.532, validationLoss = 0.648 (minibatch size = 16)
# Epoch 1 Batch 590: trainingAccuracy = 0.742, validationAccuracy = 0.698 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 600: trainingLoss = 0.529, validationLoss = 0.416 (minibatch size = 16)
# Epoch 1 Batch 600: trainingAccuracy = 0.744, validationAccuracy = 0.816 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 610: trainingLoss = 0.526, validationLoss = 0.433 (minibatch size = 16)
# Epoch 1 Batch 610: trainingAccuracy = 0.746, validationAccuracy = 0.813 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 1 Batch 620: trainingLoss = 0.525, validationLoss = 0.557 (minibatch size = 16)
# Epoch 1 Batch 620: trainingAccuracy = 0.747, validationAccuracy = 0.759 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 630: trainingLoss = 0.523, validationLoss = 0.896 (minibatch size = 16)
# Epoch 2 Batch 630: trainingAccuracy = 0.747, validationAccuracy = 0.595 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 640: trainingLoss = 0.521, validationLoss = 0.839 (minibatch size = 16)
# Epoch 2 Batch 640: trainingAccuracy = 0.749, validationAccuracy = 0.671 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 650: trainingLoss = 0.520, validationLoss = 0.445 (minibatch size = 16)
# Epoch 2 Batch 650: trainingAccuracy = 0.750, validationAccuracy = 0.821 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 660: trainingLoss = 0.518, validationLoss = 0.401 (minibatch size = 16)
# Epoch 2 Batch 660: trainingAccuracy = 0.751, validationAccuracy = 0.885 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 670: trainingLoss = 0.516, validationLoss = 0.531 (minibatch size = 16)
# Epoch 2 Batch 670: trainingAccuracy = 0.752, validationAccuracy = 0.776 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 680: trainingLoss = 0.514, validationLoss = 0.578 (minibatch size = 16)
# Epoch 2 Batch 680: trainingAccuracy = 0.754, validationAccuracy = 0.764 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 690: trainingLoss = 0.512, validationLoss = 0.599 (minibatch size = 16)
# Epoch 2 Batch 690: trainingAccuracy = 0.755, validationAccuracy = 0.747 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 700: trainingLoss = 0.509, validationLoss = 0.810 (minibatch size = 16)
# Epoch 2 Batch 700: trainingAccuracy = 0.757, validationAccuracy = 0.580 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 710: trainingLoss = 0.507, validationLoss = 0.529 (minibatch size = 16)
# Epoch 2 Batch 710: trainingAccuracy = 0.758, validationAccuracy = 0.784 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 720: trainingLoss = 0.505, validationLoss = 0.376 (minibatch size = 16)
# Epoch 2 Batch 720: trainingAccuracy = 0.759, validationAccuracy = 0.843 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 730: trainingLoss = 0.503, validationLoss = 0.447 (minibatch size = 16)
# Epoch 2 Batch 730: trainingAccuracy = 0.760, validationAccuracy = 0.816 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 740: trainingLoss = 0.502, validationLoss = 0.369 (minibatch size = 16)
# Epoch 2 Batch 740: trainingAccuracy = 0.761, validationAccuracy = 0.848 (minibatch size = 16)
# Oh yah
# Calculating Validation Accuracy...
# Epoch 2 Batch 750: trainingLoss = 0.501, validationLoss = 0.461 (minibatch size = 16)
# Epoch 2 Batch 750: trainingAccuracy = 0.762, validationAccuracy = 0.779 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 760: trainingLoss = 0.499, validationLoss = 0.647 (minibatch size = 16)
# Epoch 2 Batch 760: trainingAccuracy = 0.763, validationAccuracy = 0.744 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 770: trainingLoss = 0.498, validationLoss = 0.515 (minibatch size = 16)
# Epoch 2 Batch 770: trainingAccuracy = 0.763, validationAccuracy = 0.752 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 780: trainingLoss = 0.497, validationLoss = 1.103 (minibatch size = 16)
# Epoch 2 Batch 780: trainingAccuracy = 0.764, validationAccuracy = 0.467 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 790: trainingLoss = 0.496, validationLoss = 0.528 (minibatch size = 16)
# Epoch 2 Batch 790: trainingAccuracy = 0.765, validationAccuracy = 0.749 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 800: trainingLoss = 0.494, validationLoss = 0.380 (minibatch size = 16)
# Epoch 2 Batch 800: trainingAccuracy = 0.766, validationAccuracy = 0.850 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 810: trainingLoss = 0.492, validationLoss = 0.555 (minibatch size = 16)
# Epoch 2 Batch 810: trainingAccuracy = 0.767, validationAccuracy = 0.749 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 820: trainingLoss = 0.490, validationLoss = 0.567 (minibatch size = 16)
# Epoch 2 Batch 820: trainingAccuracy = 0.769, validationAccuracy = 0.754 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 830: trainingLoss = 0.488, validationLoss = 0.587 (minibatch size = 16)
# Epoch 2 Batch 830: trainingAccuracy = 0.770, validationAccuracy = 0.742 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 840: trainingLoss = 0.488, validationLoss = 1.244 (minibatch size = 16)
# Epoch 2 Batch 840: trainingAccuracy = 0.770, validationAccuracy = 0.477 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 850: trainingLoss = 0.486, validationLoss = 0.862 (minibatch size = 16)
# Epoch 2 Batch 850: trainingAccuracy = 0.771, validationAccuracy = 0.703 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 860: trainingLoss = 0.484, validationLoss = 0.411 (minibatch size = 16)
# Epoch 2 Batch 860: trainingAccuracy = 0.772, validationAccuracy = 0.823 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 870: trainingLoss = 0.482, validationLoss = 0.440 (minibatch size = 16)
# Epoch 2 Batch 870: trainingAccuracy = 0.773, validationAccuracy = 0.843 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 880: trainingLoss = 0.481, validationLoss = 0.577 (minibatch size = 16)
# Epoch 2 Batch 880: trainingAccuracy = 0.773, validationAccuracy = 0.870 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 890: trainingLoss = 0.481, validationLoss = 0.948 (minibatch size = 16)
# Epoch 2 Batch 890: trainingAccuracy = 0.774, validationAccuracy = 0.572 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 900: trainingLoss = 0.480, validationLoss = 1.358 (minibatch size = 16)
# Epoch 2 Batch 900: trainingAccuracy = 0.774, validationAccuracy = 0.486 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 910: trainingLoss = 0.478, validationLoss = 0.549 (minibatch size = 16)
# Epoch 2 Batch 910: trainingAccuracy = 0.775, validationAccuracy = 0.776 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 920: trainingLoss = 0.476, validationLoss = 0.431 (minibatch size = 16)
# Epoch 2 Batch 920: trainingAccuracy = 0.776, validationAccuracy = 0.848 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 2 Batch 930: trainingLoss = 0.475, validationLoss = 0.446 (minibatch size = 16)
# Epoch 2 Batch 930: trainingAccuracy = 0.777, validationAccuracy = 0.848 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 940: trainingLoss = 0.473, validationLoss = 1.015 (minibatch size = 16)
# Epoch 3 Batch 940: trainingAccuracy = 0.778, validationAccuracy = 0.629 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 950: trainingLoss = 0.470, validationLoss = 0.941 (minibatch size = 16)
# Epoch 3 Batch 950: trainingAccuracy = 0.779, validationAccuracy = 0.688 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 960: trainingLoss = 0.468, validationLoss = 0.785 (minibatch size = 16)
# Epoch 3 Batch 960: trainingAccuracy = 0.780, validationAccuracy = 0.649 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 970: trainingLoss = 0.466, validationLoss = 1.054 (minibatch size = 16)
# Epoch 3 Batch 970: trainingAccuracy = 0.781, validationAccuracy = 0.585 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 980: trainingLoss = 0.464, validationLoss = 0.373 (minibatch size = 16)
# Epoch 3 Batch 980: trainingAccuracy = 0.782, validationAccuracy = 0.870 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 990: trainingLoss = 0.462, validationLoss = 0.381 (minibatch size = 16)
# Epoch 3 Batch 990: trainingAccuracy = 0.783, validationAccuracy = 0.875 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1000: trainingLoss = 0.461, validationLoss = 0.631 (minibatch size = 16)
# Epoch 3 Batch 1000: trainingAccuracy = 0.784, validationAccuracy = 0.737 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1010: trainingLoss = 0.459, validationLoss = 0.579 (minibatch size = 16)
# Epoch 3 Batch 1010: trainingAccuracy = 0.785, validationAccuracy = 0.781 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1020: trainingLoss = 0.458, validationLoss = 0.581 (minibatch size = 16)
# Epoch 3 Batch 1020: trainingAccuracy = 0.785, validationAccuracy = 0.771 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1030: trainingLoss = 0.456, validationLoss = 0.414 (minibatch size = 16)
# Epoch 3 Batch 1030: trainingAccuracy = 0.786, validationAccuracy = 0.862 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1040: trainingLoss = 0.454, validationLoss = 0.822 (minibatch size = 16)
# Epoch 3 Batch 1040: trainingAccuracy = 0.787, validationAccuracy = 0.744 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1050: trainingLoss = 0.452, validationLoss = 0.861 (minibatch size = 16)
# Epoch 3 Batch 1050: trainingAccuracy = 0.788, validationAccuracy = 0.686 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1060: trainingLoss = 0.450, validationLoss = 1.421 (minibatch size = 16)
# Epoch 3 Batch 1060: trainingAccuracy = 0.790, validationAccuracy = 0.501 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1070: trainingLoss = 0.447, validationLoss = 1.069 (minibatch size = 16)
# Epoch 3 Batch 1070: trainingAccuracy = 0.791, validationAccuracy = 0.683 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1080: trainingLoss = 0.446, validationLoss = 1.160 (minibatch size = 16)
# Epoch 3 Batch 1080: trainingAccuracy = 0.792, validationAccuracy = 0.639 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1090: trainingLoss = 0.445, validationLoss = 0.486 (minibatch size = 16)
# Epoch 3 Batch 1090: trainingAccuracy = 0.793, validationAccuracy = 0.799 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1100: trainingLoss = 0.443, validationLoss = 0.673 (minibatch size = 16)
# Epoch 3 Batch 1100: trainingAccuracy = 0.793, validationAccuracy = 0.703 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1110: trainingLoss = 0.442, validationLoss = 1.091 (minibatch size = 16)
# Epoch 3 Batch 1110: trainingAccuracy = 0.794, validationAccuracy = 0.548 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1120: trainingLoss = 0.441, validationLoss = 0.470 (minibatch size = 16)
# Epoch 3 Batch 1120: trainingAccuracy = 0.795, validationAccuracy = 0.821 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1130: trainingLoss = 0.439, validationLoss = 0.539 (minibatch size = 16)
# Epoch 3 Batch 1130: trainingAccuracy = 0.796, validationAccuracy = 0.786 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1140: trainingLoss = 0.437, validationLoss = 0.441 (minibatch size = 16)
# Epoch 3 Batch 1140: trainingAccuracy = 0.797, validationAccuracy = 0.853 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1150: trainingLoss = 0.435, validationLoss = 0.447 (minibatch size = 16)
# Epoch 3 Batch 1150: trainingAccuracy = 0.798, validationAccuracy = 0.872 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1160: trainingLoss = 0.434, validationLoss = 0.583 (minibatch size = 16)
# Epoch 3 Batch 1160: trainingAccuracy = 0.798, validationAccuracy = 0.754 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1170: trainingLoss = 0.434, validationLoss = 0.413 (minibatch size = 16)
# Epoch 3 Batch 1170: trainingAccuracy = 0.798, validationAccuracy = 0.862 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1180: trainingLoss = 0.433, validationLoss = 0.677 (minibatch size = 16)
# Epoch 3 Batch 1180: trainingAccuracy = 0.799, validationAccuracy = 0.690 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1190: trainingLoss = 0.432, validationLoss = 0.724 (minibatch size = 16)
# Epoch 3 Batch 1190: trainingAccuracy = 0.800, validationAccuracy = 0.678 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1200: trainingLoss = 0.430, validationLoss = 0.638 (minibatch size = 16)
# Epoch 3 Batch 1200: trainingAccuracy = 0.801, validationAccuracy = 0.754 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1210: trainingLoss = 0.428, validationLoss = 0.488 (minibatch size = 16)
# Epoch 3 Batch 1210: trainingAccuracy = 0.801, validationAccuracy = 0.845 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1220: trainingLoss = 0.427, validationLoss = 0.662 (minibatch size = 16)
# Epoch 3 Batch 1220: trainingAccuracy = 0.802, validationAccuracy = 0.796 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1230: trainingLoss = 0.426, validationLoss = 0.471 (minibatch size = 16)
# Epoch 3 Batch 1230: trainingAccuracy = 0.803, validationAccuracy = 0.799 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 3 Batch 1240: trainingLoss = 0.425, validationLoss = 0.614 (minibatch size = 16)
# Epoch 3 Batch 1240: trainingAccuracy = 0.803, validationAccuracy = 0.791 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1250: trainingLoss = 0.424, validationLoss = 1.099 (minibatch size = 16)
# Epoch 4 Batch 1250: trainingAccuracy = 0.804, validationAccuracy = 0.604 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1260: trainingLoss = 0.422, validationLoss = 0.428 (minibatch size = 16)
# Epoch 4 Batch 1260: trainingAccuracy = 0.805, validationAccuracy = 0.853 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1270: trainingLoss = 0.420, validationLoss = 0.427 (minibatch size = 16)
# Epoch 4 Batch 1270: trainingAccuracy = 0.806, validationAccuracy = 0.880 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1280: trainingLoss = 0.418, validationLoss = 0.397 (minibatch size = 16)
# Epoch 4 Batch 1280: trainingAccuracy = 0.807, validationAccuracy = 0.857 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1290: trainingLoss = 0.416, validationLoss = 0.537 (minibatch size = 16)
# Epoch 4 Batch 1290: trainingAccuracy = 0.808, validationAccuracy = 0.789 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1300: trainingLoss = 0.414, validationLoss = 0.464 (minibatch size = 16)
# Epoch 4 Batch 1300: trainingAccuracy = 0.809, validationAccuracy = 0.833 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1310: trainingLoss = 0.413, validationLoss = 0.698 (minibatch size = 16)
# Epoch 4 Batch 1310: trainingAccuracy = 0.810, validationAccuracy = 0.776 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1320: trainingLoss = 0.410, validationLoss = 0.690 (minibatch size = 16)
# Epoch 4 Batch 1320: trainingAccuracy = 0.811, validationAccuracy = 0.774 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1330: trainingLoss = 0.409, validationLoss = 0.445 (minibatch size = 16)
# Epoch 4 Batch 1330: trainingAccuracy = 0.812, validationAccuracy = 0.865 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1340: trainingLoss = 0.407, validationLoss = 0.526 (minibatch size = 16)
# Epoch 4 Batch 1340: trainingAccuracy = 0.813, validationAccuracy = 0.806 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1350: trainingLoss = 0.405, validationLoss = 1.087 (minibatch size = 16)
# Epoch 4 Batch 1350: trainingAccuracy = 0.813, validationAccuracy = 0.656 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1360: trainingLoss = 0.403, validationLoss = 0.756 (minibatch size = 16)
# Epoch 4 Batch 1360: trainingAccuracy = 0.815, validationAccuracy = 0.737 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1370: trainingLoss = 0.401, validationLoss = 0.621 (minibatch size = 16)
# Epoch 4 Batch 1370: trainingAccuracy = 0.816, validationAccuracy = 0.816 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1380: trainingLoss = 0.399, validationLoss = 1.411 (minibatch size = 16)
# Epoch 4 Batch 1380: trainingAccuracy = 0.817, validationAccuracy = 0.676 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1390: trainingLoss = 0.397, validationLoss = 1.068 (minibatch size = 16)
# Epoch 4 Batch 1390: trainingAccuracy = 0.818, validationAccuracy = 0.708 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1400: trainingLoss = 0.395, validationLoss = 0.711 (minibatch size = 16)
# Epoch 4 Batch 1400: trainingAccuracy = 0.819, validationAccuracy = 0.740 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1410: trainingLoss = 0.393, validationLoss = 0.633 (minibatch size = 16)
# Epoch 4 Batch 1410: trainingAccuracy = 0.820, validationAccuracy = 0.737 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1420: trainingLoss = 0.391, validationLoss = 0.925 (minibatch size = 16)
# Epoch 4 Batch 1420: trainingAccuracy = 0.820, validationAccuracy = 0.705 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1430: trainingLoss = 0.390, validationLoss = 1.042 (minibatch size = 16)
# Epoch 4 Batch 1430: trainingAccuracy = 0.821, validationAccuracy = 0.799 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1440: trainingLoss = 0.389, validationLoss = 0.768 (minibatch size = 16)
# Epoch 4 Batch 1440: trainingAccuracy = 0.822, validationAccuracy = 0.811 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1450: trainingLoss = 0.387, validationLoss = 0.728 (minibatch size = 16)
# Epoch 4 Batch 1450: trainingAccuracy = 0.823, validationAccuracy = 0.799 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1460: trainingLoss = 0.386, validationLoss = 1.041 (minibatch size = 16)
# Epoch 4 Batch 1460: trainingAccuracy = 0.823, validationAccuracy = 0.671 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1470: trainingLoss = 0.384, validationLoss = 0.754 (minibatch size = 16)
# Epoch 4 Batch 1470: trainingAccuracy = 0.824, validationAccuracy = 0.744 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1480: trainingLoss = 0.383, validationLoss = 0.816 (minibatch size = 16)
# Epoch 4 Batch 1480: trainingAccuracy = 0.825, validationAccuracy = 0.784 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1490: trainingLoss = 0.381, validationLoss = 0.664 (minibatch size = 16)
# Epoch 4 Batch 1490: trainingAccuracy = 0.826, validationAccuracy = 0.771 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1500: trainingLoss = 0.380, validationLoss = 0.813 (minibatch size = 16)
# Epoch 4 Batch 1500: trainingAccuracy = 0.826, validationAccuracy = 0.725 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1510: trainingLoss = 0.379, validationLoss = 0.719 (minibatch size = 16)
# Epoch 4 Batch 1510: trainingAccuracy = 0.827, validationAccuracy = 0.713 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1520: trainingLoss = 0.377, validationLoss = 1.151 (minibatch size = 16)
# Epoch 4 Batch 1520: trainingAccuracy = 0.828, validationAccuracy = 0.607 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1530: trainingLoss = 0.376, validationLoss = 0.750 (minibatch size = 16)
# Epoch 4 Batch 1530: trainingAccuracy = 0.829, validationAccuracy = 0.779 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1540: trainingLoss = 0.374, validationLoss = 0.703 (minibatch size = 16)
# Epoch 4 Batch 1540: trainingAccuracy = 0.829, validationAccuracy = 0.806 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 4 Batch 1550: trainingLoss = 0.373, validationLoss = 0.662 (minibatch size = 16)
# Epoch 4 Batch 1550: trainingAccuracy = 0.830, validationAccuracy = 0.801 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1560: trainingLoss = 0.372, validationLoss = 0.543 (minibatch size = 16)
# Epoch 5 Batch 1560: trainingAccuracy = 0.831, validationAccuracy = 0.855 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1570: trainingLoss = 0.370, validationLoss = 0.674 (minibatch size = 16)
# Epoch 5 Batch 1570: trainingAccuracy = 0.832, validationAccuracy = 0.813 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1580: trainingLoss = 0.368, validationLoss = 1.212 (minibatch size = 16)
# Epoch 5 Batch 1580: trainingAccuracy = 0.832, validationAccuracy = 0.661 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1590: trainingLoss = 0.367, validationLoss = 1.218 (minibatch size = 16)
# Epoch 5 Batch 1590: trainingAccuracy = 0.833, validationAccuracy = 0.636 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1600: trainingLoss = 0.365, validationLoss = 1.123 (minibatch size = 16)
# Epoch 5 Batch 1600: trainingAccuracy = 0.834, validationAccuracy = 0.663 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1610: trainingLoss = 0.363, validationLoss = 0.894 (minibatch size = 16)
# Epoch 5 Batch 1610: trainingAccuracy = 0.835, validationAccuracy = 0.752 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1620: trainingLoss = 0.361, validationLoss = 1.073 (minibatch size = 16)
# Epoch 5 Batch 1620: trainingAccuracy = 0.835, validationAccuracy = 0.720 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1630: trainingLoss = 0.359, validationLoss = 0.803 (minibatch size = 16)
# Epoch 5 Batch 1630: trainingAccuracy = 0.836, validationAccuracy = 0.784 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1640: trainingLoss = 0.358, validationLoss = 0.657 (minibatch size = 16)
# Epoch 5 Batch 1640: trainingAccuracy = 0.837, validationAccuracy = 0.791 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1650: trainingLoss = 0.356, validationLoss = 0.968 (minibatch size = 16)
# Epoch 5 Batch 1650: trainingAccuracy = 0.838, validationAccuracy = 0.774 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1660: trainingLoss = 0.354, validationLoss = 0.740 (minibatch size = 16)
# Epoch 5 Batch 1660: trainingAccuracy = 0.839, validationAccuracy = 0.813 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1670: trainingLoss = 0.353, validationLoss = 1.470 (minibatch size = 16)
# Epoch 5 Batch 1670: trainingAccuracy = 0.840, validationAccuracy = 0.683 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1680: trainingLoss = 0.352, validationLoss = 1.216 (minibatch size = 16)
# Epoch 5 Batch 1680: trainingAccuracy = 0.840, validationAccuracy = 0.732 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1690: trainingLoss = 0.350, validationLoss = 0.635 (minibatch size = 16)
# Epoch 5 Batch 1690: trainingAccuracy = 0.841, validationAccuracy = 0.808 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1700: trainingLoss = 0.350, validationLoss = 1.330 (minibatch size = 16)
# Epoch 5 Batch 1700: trainingAccuracy = 0.841, validationAccuracy = 0.764 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1710: trainingLoss = 0.349, validationLoss = 0.642 (minibatch size = 16)
# Epoch 5 Batch 1710: trainingAccuracy = 0.842, validationAccuracy = 0.821 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1720: trainingLoss = 0.348, validationLoss = 0.499 (minibatch size = 16)
# Epoch 5 Batch 1720: trainingAccuracy = 0.842, validationAccuracy = 0.860 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1730: trainingLoss = 0.347, validationLoss = 0.797 (minibatch size = 16)
# Epoch 5 Batch 1730: trainingAccuracy = 0.843, validationAccuracy = 0.799 (minibatch size = 16)
# Calculating Validation Accuracy...
# Epoch 5 Batch 1740: trainingLoss = 0.346, validationLoss = 0.549 (minibatch size = 16)
# Epoch 5 Batch 1740: trainingAccuracy = 0.843, validationAccuracy = 0.833 (minibatch size = 16)
# early stop1
# early stop2

# %%
my_model.load_state_dict(torch.load(PATH)) #use the saved model to test
# Out:
# <All keys matched successfully>

# %%
my_model.eval()
print("Doing model testing...")
test_nobs = 0
ncorrect = 0
pred_list = []
true_list = []
outputs_list = []
targets_list = []
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_loader):            
        inputs, targets = inputs.to(device), targets.to(device)
        targets = targets.reshape((-1, 1))
        outputs = my_model(inputs)
        targets = targets.float()
        outputs_list.append(outputs)
        targets_list.append(targets)              
        pred = (outputs.cpu().numpy() > 0.5).astype('float32')
        pred_list.extend(pred.flatten().tolist())
        true_list.extend(targets.flatten().tolist())
        tmp_correct = (pred == targets.cpu().numpy()).sum()
        ncorrect += tmp_correct
        test_nobs += len(pred)        
accuracy = ncorrect / test_nobs
#print(np.array(outputs_list))
#print(np.array(outputs_list).shape)
#print(np.array(targets_list))
#print(np.array(targets_list).shape)
outputs_array = np.array(outputs_list)
for i in range(len(outputs_array)):
  outputs_array[i] = outputs_array[i].to("cpu")
  outputs_array[i] = outputs_array[i].numpy()
full_test_outputs = np.concatenate(outputs_array, axis=0 )
targets_array = np.array(targets_list)
for i in range(len(targets_array)):
  targets_array[i] = targets_array[i].to("cpu")
  targets_array[i] = targets_array[i].numpy()
full_test_targets = np.concatenate(targets_array, axis=0 )
testloss = loss_fn(torch.tensor(full_test_outputs), torch.tensor(full_test_targets))
print("Test loss = %.3f" % testloss.item())
print("Accuracy = %.3f" % accuracy)
# Out:
# Doing model testing...
# Test loss = 0.434
# Accuracy = 0.822

# %%
outputs_array = np.array(outputs_list)
for i in range(len(outputs_array)):
  outputs_array[i] = outputs_array[i].to("cpu")
  outputs_array[i] = outputs_array[i].numpy()
full_test_outputs = np.concatenate(outputs_array, axis=0 )
targets_array = np.array(targets_list)
for i in range(len(targets_array)):
  targets_array[i] = targets_array[i].to("cpu")
  targets_array[i] = targets_array[i].numpy()
full_test_targets = np.concatenate(targets_array, axis=0 )
testloss = loss_fn(torch.tensor(full_test_outputs), torch.tensor(full_test_targets))

# %%
from sklearn import metrics
from sklearn.metrics import roc_auc_score
print(metrics.classification_report(true_list, pred_list))
print("AUC:",roc_auc_score(true_list, pred_list))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90       359
#          1.0       0.20      0.20      0.20        45
#
#     accuracy                           0.82       404
#    macro avg       0.55      0.55      0.55       404
# weighted avg       0.82      0.82      0.82       404
#
# AUC: 0.5498607242339832

# %%
# !cp resnet18_new2.pth "drive/My Drive"

# %%
import matplotlib.pyplot as plt
plt.plot(step_count_list, trainingloss_list, label = "training loss")
plt.plot(step_count_list, validloss_list, label = "validation loss")
plt.legend()
plt.show()
